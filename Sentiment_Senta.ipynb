# %%
# This note book is for sentiment analysis (Baidu Senta) only.
# I seperate the file because the library requires 64bit machine and google colab can provide the environment.
# @author LI, Jingchen
# install packages
# !pip install paddlepaddle==2.0.0rc0 -i https://mirror.baidu.com/pypi/simple
# !pip install paddlehub==2.0.0b1
# Out:
# Looking in indexes: https://mirror.baidu.com/pypi/simple
# ...
#      |████████████████████████████████| 127.5MB 76kB/s
# ...

# %%
pip install sentencepiece
# Out:
# ...
#      |████████████████████████████████| 1.1MB 9.8MB/s
# ...

# %%
# initialze the function and do some simple test
import paddlehub as hub
senta = hub.Module(name="senta_bilstm")
test_text = ["味道不错，确实不算太辣，适合不能吃辣的人。就在长江边上，抬头就能看到长江的风景。鸭肠、黄鳝都比较新鲜。"]
res = senta.sentiment_classify(texts = test_text)

print("情感分析结果：", res)
# Out:
# Download https://bj.bcebos.com/paddlehub/paddlehub_dev/senta_bilstm_1.2.0.tar.gz
# [##################################################] 100.00%
# Decompress /root/.paddlehub/tmp/tmpforh0j71/senta_bilstm_1.2.0.tar.gz
# [##################################################] 100.00%
# [2020-12-19 06:07:54,520] [    INFO] - Successfully installed senta_bilstm-1.2.0
# [2020-12-19 06:07:54,728] [ WARNING] - The _initialize method in HubModule will soon be deprecated, you can use the __init__() to handle the initialization of the object
# Download https://bj.bcebos.com/paddlehub/paddlehub_dev/lac_2.2.0.tar.gz
# [##################################################] 100.00%
# Decompress /root/.paddlehub/tmp/tmp1jnd_moa/lac_2.2.0.tar.gz
# [##################################################] 100.00%
# [2020-12-19 06:08:16,286] [    INFO] - Successfully installed lac-2.2.0
# ...

# %%
# upload the data
from google.colab import files
uploaded = files.upload()
import io
Expedition930 = pd.read_csv(io.BytesIO(uploaded['seventh_expedition_expedition_data.csv']))

# %%
Expedition930.head()
# Out:
#        id  parent_id  ...  attachment.type group
# 0  243203     206156  ...              NaN   bbc
# 1  243204     206156  ...              NaN   bbc
# 2  243206     206156  ...              NaN   bbc
# 3  243221     206156  ...              NaN   bbc
# 4  243224     206157  ...              NaN   bbc
#
# [5 rows x 14 columns]

# %%
# process the data for the sentiment analysis.
text = []
for i in range(len(Expedition930)):
  text.append(Expedition930['message'].astype(str)[i])

# %%
# predicte the result 
Result = senta.sentiment_classify(texts = text)

# %%
# write the processed data to csv
my_df = pd.DataFrame(Result)

my_df.to_csv('sentiment930.csv', index=False, header=True)

# %%
# download the processed data
files.download("sentiment930.csv")
